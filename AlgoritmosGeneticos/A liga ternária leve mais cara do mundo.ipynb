# %%
preco = {
    "H": 1.39,
    "He": 24,
    "Li": 85.6,
    "Be": 857,
    "B": 3.68,
    "C": 0.122,
    "N": 0.14,
    "O": 0.154,
    "F": 2.16,
    "Ne": 240,
    "Na": 3.43,
    "Mg": 2.32,
    "Al": 1.79,
    "Si": 1.7,
    "P": 2.69,
    "S": 0.0926,
    "Cl": 0.082,
    "Ar": 0.931,
    "K": 13.6,
    "Ca": 2.35,
    "Sc": 3460,
    "Ti": 11.7,
    "V": 385,
    "Cr": 9.4,
    "Mn": 1.82,
    "Fe": 0.424,
    "Co": 32.8,
    "Ni": 13.9,
    "Cu": 6,
    "Zn": 2.55,
    "Ga": 148,
    "Ge": 1010,
    "As": 1.31,
    "Se": 21.4,
    "Br": 4.39,
    "Kr": 290,
    "Rb": 15500,
    "Sr": 6.68,
    "Y": 31,
    "Nb": 85.6,
    "Mo": 40.1,
    "Tc": 100000,
    "Ru": 10600,
    "Rh": 147000,
    "Pd": 49500,
    "Ag": 521,
    "Cd": 2.73,
    "In": 167,
    "Sn": 18.7,
    "Sb": 5.79,
    "Te": 63.5,
    "I": 35,
    "Xe": 1800,
    "Cs": 61800,
    "Ba": 0.275,
    "La": 4.92,
    "Ce": 4.71,
    "Pr": 103,
    "Nd": 57.5,
    "Pm": 460000,
    "Sm": 13.9,
    "Eu": 31.4,
    "Gd": 28.6,
    "Tb": 658,
    "Dy": 307,
    "Ho": 57.1,
    "Er": 26.4,
    "Tm": 3000,
    "Yb": 17.1,
    "Lu": 643,
    "Hf": 900,
    "Ta": 312,
    "W": 35.3,
    "Re": 4150,
    "Os": 12000,
    "Ir": 56200,
    "Pt": 27800,
    "Hg": 30.2,
    "Tl": 4200,
    "Pb": 2,
    "Bi": 6.36,
    "Po": 49200000000000,
    "Ac": 29000000000000,
    "Th": 287,
    "Pa": 280000,
    "U": 101,
    "Np": 660000,
    "Pu": 6490000,
    "Am": 750000,
    "Cm": 160000000000,
    "Bk": 185000000000,
    "Cf": 185000000000,
}

# definindo as restrições
def constantes(xyz):
    x, y, z = xyz
    return x + y + z == 100 and x > 5 and y > 5 and z > 5

# gerando uma população inicial aleatória
import random

populacao_inicial = []
for i in range(100):
    x = random.randint(6, 94)
    y = random.randint(6, 94 - x)
    z = 100 - x - y
    populacao_inicial.append((x, y, z))

# definindo a função de fitness
def fitness(xyz):
    x, y, z = xyz
    return -(x*preco["A"] + y*preco["B"] + z*preco["C"])

# rodando o algoritmo genético
from a_g import g_a

ga = a_g(populacao_inicial=populacao_inicial,
                      fitness_function=fitness,
                      constraint_function=constantes,
                      mutation_rate=0.1,
                      max_generations=100)

best_solution = ga.run()
print(best_solution)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\CAIO22~1\AppData\Local\Temp/ipykernel_20176/1965208337.py in <module>
#     105 for i in range(100):
#     106     x = random.randint(6, 94)
# --> 107     y = random.randint(6, 94 - x)
#     108     z = 100 - x - y
#     109     populacao_inicial.append((x, y, z))
#
# C:\Program Files\Python39\lib\random.py in randint(self, a, b)
#     336         """
#     337
# --> 338         return self.randrange(a, b+1)
#     339
#     340
#
# C:\Program Files\Python39\lib\random.py in randrange(self, start, stop, step)
#     314             return istart + self._randbelow(width)
#     315         if step == 1:
# --> 316             raise ValueError("empty range for randrange() (%d, %d, %d)" % (istart, istop, width))
#     317
#     318         # Non-unit step argument supplied.
#
# ValueError: empty range for randrange() (6, 3, -3)
