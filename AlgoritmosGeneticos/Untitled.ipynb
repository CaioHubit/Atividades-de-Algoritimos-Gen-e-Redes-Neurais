# %%
import random

from funcoes import cruzamento_ordenado

from funcoes import individuo_LMC
from funcoes import mutacao_de_troca
from funcoes import populacao_inicial_LMC
from funcoes import funcao_objetivo_pop_LMC
from funcoes import selecao_roleta_max
from funcoes import cruzamento_ponto_simples_LMC

# %%
# preço em dólares por kilograma
preco = {
    "H": 1.39,
    "He": 24,
    "Li": 85.6,
    "Be": 857,
    "B": 3.68,
    "C": 0.122,
    "N": 0.14,
    "O": 0.154,
    "F": 2.16,
    "Ne": 240,
    "Na": 3.43,
    "Mg": 2.32,
    "Al": 1.79,
    "Si": 1.7,
    "P": 2.69,
    "S": 0.0926,
    "Cl": 0.082,
    "Ar": 0.931,
    "K": 13.6,
    "Ca": 2.35,
    "Sc": 3460,
    "Ti": 11.7,
    "V": 385,
    "Cr": 9.4,
    "Mn": 1.82,
    "Fe": 0.424,
    "Co": 32.8,
    "Ni": 13.9,
    "Cu": 6,
    "Zn": 2.55,
    "Ga": 148,
    "Ge": 1010,
    "As": 1.31,
    "Se": 21.4,
    "Br": 4.39,
    "Kr": 290,
    "Rb": 15500,
    "Sr": 6.68,
    "Y": 31,
    "Nb": 85.6,
    "Mo": 40.1,
    "Tc": 100000,
    "Ru": 10600,
    "Rh": 147000,
    "Pd": 49500,
    "Ag": 521,
    "Cd": 2.73,
    "In": 167,
    "Sn": 18.7,
    "Sb": 5.79,
    "Te": 63.5,
    "I": 35,
    "Xe": 1800,
    "Cs": 61800,
    "Ba": 0.275,
    "La": 4.92,
    "Ce": 4.71,
    "Pr": 103,
    "Nd": 57.5,
    "Pm": 460000,
    "Sm": 13.9,
    "Eu": 31.4,
    "Gd": 28.6,
    "Tb": 658,
    "Dy": 307,
    "Ho": 57.1,
    "Er": 26.4,
    "Tm": 3000,
    "Yb": 17.1,
    "Lu": 643,
    "Hf": 900,
    "Ta": 312,
    "W": 35.3,
    "Re": 4150,
    "Os": 12000,
    "Ir": 56200,
    "Pt": 27800,
    "Hg": 30.2,
    "Tl": 4200,
    "Pb": 2,
    "Bi": 6.36,
    "Po": 49200000000000,
    "Ac": 29000000000000,
    "Th": 287,
    "Pa": 280000,
    "U": 101,
    "Np": 660000,
    "Pu": 6490000,
    "Am": 750000,
    "Cm": 160000000000,
    "Bk": 185000000000,
    "Cf": 185000000000,
}

# %%
def cria_populacao_inicial(n_genes, tamanho, preco):
    return populacao_inicial_LMC(n_genes, tamanho, preco)

def funcao_mutacao(individuo):
    return mutacao_de_troca(individuo)

def funcao_objetivo_pop(populacao, preco):
    return funcao_objetivo_pop_LMC(populacao, preco)

def funcao_selecao(populacao,fitness):
    return selecao_roleta_max(populacao,fitness)

def cruzamento_ponto_simples(pai, mae, n_genes):
    return cruzamento_ponto_simples_LMC(pai, mae, n_genes)

# %%
N_GENES = 3 # Já que é de liga ternária
TAMANHO_POP = 50
NUM_GERACOES = 5
CHANCE_CRUZAMENTO = 0.5
CHANCE_MUTACAO = 0.05

# %%
populacao = cria_populacao_inicial(N_GENES, TAMANHO_POP, preco)

for _ in range(NUM_GERACOES):
    fitness = funcao_objetivo_pop(populacao, preco)    
    populacao = funcao_selecao(populacao,fitness)    
    
    pais = populacao[0::2]
    maes = populacao[1::2]
    
    contador = 0
    
    for pai, mae in zip(pais,maes):
        if random.random() < CHANCE_CRUZAMENTO:
            filho1, filho2 = cruzamento_ponto_simples(pai,mae,N_GENES)
            populacao[contador] = filho1
            populacao[contador+1] = filho2
        contador += 2
    
    
    for n in range(len(populacao)):
        if random.random() <= CHANCE_MUTACAO:
            #print(f'Indivíduo mutado: {populacao[n]}',end=' ')
            populacao[n] = funcao_mutacao(populacao[n])
            #print(populacao[n])

print(f'A liga escolhida com um preço de {round(max(fitness)/1e9,2)} trilhões de dólares, detém as seguintes características:\n')

liga_escolhida = populacao[fitness.index(max(fitness))]
for elemento, quantidade in zip(list(preco.keys()),liga_escolhida):
    if quantidade != 0:
        print(f'- {elemento}: {round(quantidade,2)} gramas')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\CAIO22~1\AppData\Local\Temp/ipykernel_16120/3371597320.py in <module>
# ----> 1 populacao = cria_populacao_inicial(N_GENES, TAMANHO_POP, preco)
#       2
#       3 for _ in range(NUM_GERACOES):
#       4     fitness = funcao_objetivo_pop(populacao, preco)
#       5     populacao = funcao_selecao(populacao,fitness)
#
# C:\Users\CAIO22~1\AppData\Local\Temp/ipykernel_16120/3565387650.py in cria_populacao_inicial(n_genes, tamanho, preco)
#       1 def cria_populacao_inicial(n_genes, tamanho, preco):
# ----> 2     return populacao_inicial_LMC(n_genes, tamanho, preco)
#       3
#       4 def funcao_mutacao(individuo):
#       5     return mutacao_de_troca(individuo)
#
# C:\JupyterLab\Programação 3ºSem\Atividades-de-Algoritmos-Gen-e-Redes-Neurais\AlgoritmosGeneticos\funcoes.py in populacao_inicial_LMC(numero_genes, tamanho_populacao, preco)
#     752     populacao = []
#     753     for _ in range(tamanho_populacao):
# --> 754         populacao.append(individuo_LMC(numero_genes,preco))
#     755     return populacao
#     756
#
# C:\JupyterLab\Programação 3ºSem\Atividades-de-Algoritmos-Gen-e-Redes-Neurais\AlgoritmosGeneticos\funcoes.py in individuo_LMC(numero_genes, preco)
#     729
#     730             if individuo[index] == 0:
# --> 731                 gene = gene_LMC(valor_maximo_massa-((numero_genes-n-1)*5))
#     732                 individuo[index] = gene
#     733                 valor_maximo_massa -= gene
#
# NameError: name 'gene_lt' is not defined
